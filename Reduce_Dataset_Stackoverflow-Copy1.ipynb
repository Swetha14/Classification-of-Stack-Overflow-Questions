# %%
import pandas as pd
df = pd.read_csv('stackoverflow_reduced.csv')

# %%
df.columns
# Out:
# Index(['post', 'tags'], dtype='object')

# %%
df.head()
# Out:
#                                                 post    tags
# 0  identifying server timeout quickly in iphone  ...  iphone
# 1  distance between 2 or more drop pins  i was do...  iphone
# 2  what are all the restrictions by apple for iph...  iphone
# 3  not able to clicked on item  i have facing ver...  iphone
# 4  displaying addressbook data acording to a cert...  iphone

# %%
print("Input data has {} rows and {} columns".format(len(df), len(df.columns)))
# Out:
# Input data has 3000 rows and 2 columns

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8,6))
df.groupby('tags').post.count().plot.bar(ylim=0)

# %%
Tag = ['sql', 'iphone', 'python']

# %%
data = df[df.tags.isin(Tag)]

# %%
data
# Out:
#                                                    post    tags
# 0     identifying server timeout quickly in iphone  ...  iphone
# 1     distance between 2 or more drop pins  i was do...  iphone
# 2     what are all the restrictions by apple for iph...  iphone
# 3     not able to clicked on item  i have facing ver...  iphone
# 4     displaying addressbook data acording to a cert...  iphone
# 5     i am (also) having trouble making connections ...  iphone
# 6     issue with tab bar view displaying a compound ...  iphone
# 7     captured images from iphone camera and getting...  iphone
# 8     custom keyboard - how to dispatch event which ...  iphone
# 9     objective c on windows system  can you tell me...  iphone
# 10    playing sound from web page for iphone  i m de...  iphone
# 11    iphone full and lite version without storekit ...  iphone
# 12    uinavigationbar get white with back button  i ...  iphone
# 13    [iphone xcode]how can i get path to resource o...  iphone
# ...

# %%
import seaborn as sns

# %%
data["tags"].value_counts()
# Out:
# python    1000
# sql       1000
# iphone    1000
# Name: tags, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3000 entries, 0 to 2999
# Data columns (total 2 columns):
# post    3000 non-null object
# tags    3000 non-null object
# dtypes: object(2)
# memory usage: 70.3+ KB

# %%
sns.set(style="white", context="talk")

# %%
COLUMNS = ['iphone', 'python', 'sql']

# %%
print(data.shape)
print(data.columns.values)
# Out:
# (3000, 2)
# ['post' 'tags']
